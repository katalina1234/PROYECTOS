# %%
#EJERCICIO ACP DELITOS DEPARTAMENTAL
import numpy as np
import pandas as pd
abigeato = pd.read_excel('/content/abigeato.xlsx')
amenazas = pd.read_excel('/content/amenazas.xlsx')
delitos_sexuales = pd.read_excel('/content/delitos_sexuales.xlsx')
extorsion = pd.read_excel('/content/extorsion.xlsx')
homicidios = pd.read_excel('/content/homicidios.xlsx')
homi_transito = pd.read_excel('/content/homicidios_transito.xlsx')
hurto_automotores = pd.read_excel('/content/hurto_automotores.xlsx')
hurto_comercio = pd.read_excel('/content/hurto_comercio.xlsx')
hurto_entidades = pd.read_excel('/content/hurto_entidades_financieras.xlsx')
hurto_motocicletas = pd.read_excel('/content/hurto_motocicletas.xlsx')
hurto_personas = pd.read_excel('/content/hurto_personas.xlsx')
hurto_residencias = pd.read_excel('/content/hurto_residencias.xlsx')
lesiones_accidentes = pd.read_excel('/content/lesiones_accidentes.xlsx')
lesiones_personales = pd.read_excel('/content/lesiones_personales.xlsx')
pirateria = pd.read_excel('/content/pirateria_terrestre.xlsx')
secuestro = pd.read_excel('/content/secuestro.xlsx')
terrorismo = pd.read_excel('/content/terrorismo.xlsx')
violencia_intra = pd.read_excel('/content/violencia_intrafamiliar.xlsx')

# %%
poblacion = pd.read_excel('/content/poblacion_departamentos.xlsx')

# %% [markdown]
# #BASE

# %%
abigeato = abigeato.dropna()
amenazas = amenazas.dropna()
delitos_sexuales = delitos_sexuales.dropna()
extorsion = extorsion.dropna()
homicidios = homicidios.dropna()
homi_transito = homi_transito.dropna()
hurto_automotores = hurto_automotores.dropna()
hurto_comercio = hurto_comercio.dropna()
hurto_entidades = hurto_entidades.dropna()
hurto_motocicletas = hurto_motocicletas.dropna()
hurto_personas = hurto_personas.dropna()
hurto_residencias = hurto_residencias.dropna()
lesiones_accidentes = lesiones_accidentes.dropna()
lesiones_personales = lesiones_personales.dropna()
pirateria = pirateria.dropna()
secuestro = secuestro.dropna()
terrorismo = terrorismo.dropna()
violencia_intra = violencia_intra.dropna()
poblacion = poblacion.dropna()

# %%
#Abigeato
abigeato = abigeato.rename(columns={'CANTIDAD':'ABIGEATO'})
abigeato = abigeato.groupby('DEPARTAMENTO').sum()
abigeato.reset_index(inplace=True)

# %%
#Amenazas
amenazas = amenazas.rename(columns={'CANTIDAD':'AMENAZAS'})
amenazas = amenazas.groupby('DEPARTAMENTO').sum()
amenazas.reset_index(inplace=True)

# %%
#Delitos Sexuales
delitos_sexuales = delitos_sexuales.rename(columns={'CANTIDAD':'DELITOS_SEXUALES'})
delitos_sexuales = delitos_sexuales.groupby('DEPARTAMENTO').sum()
delitos_sexuales.reset_index(inplace=True)

# %%
#Extorsion
extorsion = extorsion.rename(columns={'CANTIDAD':'EXTORSION'})
extorsion = extorsion.groupby('DEPARTAMENTO').sum()
extorsion.reset_index(inplace=True)

# %%
#Homicidios
homicidios = homicidios.rename(columns={'CANTIDAD':'HOMICIDIOS'})
homicidios = homicidios.groupby('DEPARTAMENTO').sum()
homicidios.reset_index(inplace=True)

# %%
#Homicidios transito
homi_transito = homi_transito.rename(columns={'CANTIDAD':'HOMICIDIOS_TRANSITO'})
homi_transito= homi_transito.groupby('DEPARTAMENTO').sum()
homi_transito.reset_index(inplace=True)

# %%
#Hurto automotores
hurto_automotores = hurto_automotores.rename(columns={'CANTIDAD':'HURTO_AUTOMOTORES'})
hurto_automotores = hurto_automotores.groupby('DEPARTAMENTO').sum()
hurto_automotores.reset_index(inplace=True)

# %%
#Hurto Comercio
hurto_comercio = hurto_comercio.rename(columns={'CANTIDAD':'HURTO_COMERCIO'})
hurto_comercio = hurto_comercio.groupby('DEPARTAMENTO').sum()
hurto_comercio.reset_index(inplace=True)

# %%
#Hurto Entidades
hurto_entidades = hurto_entidades.rename(columns={'CANTIDAD':'HURTO_ENTIDADES'})
hurto_entidades = hurto_entidades.groupby('DEPARTAMENTO').sum()
hurto_entidades.reset_index(inplace=True)

# %%
#Hurto Motocicletas
hurto_motocicletas = hurto_motocicletas.rename(columns={'CANTIDAD':'HURTO_MOTOCICLETAS'})
hurto_motocicletas = hurto_motocicletas.groupby('DEPARTAMENTO').sum()
hurto_motocicletas.reset_index(inplace=True)

# %%
#Hurto Personas
hurto_personas = hurto_personas.rename(columns={'CANTIDAD':'HURTO_PERSONAS'})
hurto_personas = hurto_personas.groupby('DEPARTAMENTO').sum()
hurto_personas.reset_index(inplace=True)

# %%
#Hurto Residencias
hurto_residencias = hurto_residencias.rename(columns={'CANTIDAD':'HURTO_RESIDENCIAS'})
hurto_residencias = hurto_residencias.groupby('DEPARTAMENTO').sum()
hurto_residencias.reset_index(inplace=True)

# %%
#Lesiones Accidentes
lesiones_accidentes = lesiones_accidentes.rename(columns={'CANTIDAD':'LESIONES_ACCIDENTES'})
lesiones_accidentes = lesiones_accidentes.groupby('DEPARTAMENTO').sum()
lesiones_accidentes.reset_index(inplace=True)

# %%
#Lesiones Personales
lesiones_personales = lesiones_personales.rename(columns={'CANTIDAD':'LESIONES_PERSONALES'})
lesiones_personales = lesiones_personales.groupby('DEPARTAMENTO').sum()
lesiones_personales.reset_index(inplace=True)

# %%
#Pirateria Terrestre
pirateria = pirateria.rename(columns={'CANTIDAD':'PIRATERIA_TERRESTRE'})
pirateria = pirateria.groupby('DEPARTAMENTO').sum()
pirateria.reset_index(inplace=True)

# %%
#Secuestro
secuestro = secuestro.rename(columns={'CANTIDAD':'SECUESTRO'})
secuestro = secuestro.groupby('DEPARTAMENTO').sum()
secuestro.reset_index(inplace=True)

# %%
#Terrorismo
terrorismo = terrorismo.rename(columns={'CANTIDAD':'TERRORISMO'})
terrorismo = terrorismo.groupby('DEPARTAMENTO').sum()
terrorismo.reset_index(inplace=True)

# %%
#Violencia intrafamiliar
violencia_intra = violencia_intra.rename(columns={'CANTIDAD':'VIOLENCIA_INTRAFAMILIAR'})
violencia_intra = violencia_intra.groupby('DEPARTAMENTO').sum()
violencia_intra.reset_index(inplace=True)

# %%
dt2 = pd.concat([abigeato, amenazas, delitos_sexuales,extorsion,homicidios,homi_transito,hurto_automotores,
                 hurto_comercio,hurto_entidades,hurto_motocicletas,hurto_personas,hurto_residencias,
                 lesiones_accidentes,lesiones_personales,pirateria,secuestro,terrorismo,violencia_intra])

# %%
dt2.loc[dt2['DEPARTAMENTO'] == 'SAN ANDRÉS', 'DEPARTAMENTO'] = 'ARCHIPIÉLAGO DE SAN ANDRÉS'
dt2.loc[dt2['DEPARTAMENTO'] == 'GUAJIRA', 'DEPARTAMENTO'] = 'LA GUAJIRA'
dt2.loc[dt2['DEPARTAMENTO'] == 'QUINDÍO', 'DEPARTAMENTO'] = 'QUINDIO'
dt2.loc[dt2['DEPARTAMENTO'] == 'VALLE', 'DEPARTAMENTO'] = 'VALLE DEL CAUCA'

# %%
X = dt2.fillna(0)

# %%
Y = X.groupby('DEPARTAMENTO').sum()
Y.reset_index(inplace=True); Y
# Out:
#                   DEPARTAMENTO  ABIGEATO  ...  TERRORISMO  VIOLENCIA_INTRAFAMILIAR
# 0                     AMAZONAS       0.0  ...         0.0                    134.0
# 1                    ANTIOQUIA     178.0  ...        71.0                  16890.0
# 2                       ARAUCA      37.0  ...        63.0                    382.0
# 3   ARCHIPIÉLAGO DE SAN ANDRÉS       0.0  ...         0.0                    154.0
# 4                    ATLÁNTICO      73.0  ...         0.0                   3161.0
# 5                      BOLÍVAR     239.0  ...         0.0                   3398.0
# 6                       BOYACÁ     129.0  ...         1.0                   3651.0
# 7                       CALDAS      30.0  ...         0.0                   1400.0
# 8                      CAQUETÁ      20.0  ...         2.0                    502.0
# 9                     CASANARE     212.0  ...         0.0                    705.0
# ...

# %%
len(Y)-1#NO REGISTRA
# Out:
# 32

# %%
poblacion = poblacion.rename(columns={'DPNORM':'DEPARTAMENTO'})

# %%
poblacion
# Out:
#    DEPARTAMENTO    Total
# 0     ANTIOQUIA  5133738
# 1     ANTIOQUIA  1416468
# 2     ANTIOQUIA  6550206
# 3     ATLÁNTICO  2502642
# 4     ATLÁNTICO   135509
# ..          ...      ...
# 91       VAUPÉS    30209
# 92       VAUPÉS    42721
# 93      VICHADA    26910
# 94      VICHADA    83689
# 95      VICHADA   110599
#
# [96 rows x 2 columns]

# %%
#poblacion
poblacion = poblacion.groupby('DEPARTAMENTO').sum()
poblacion.reset_index(inplace=True)

# %%
poblacion.head()
# Out:
#                  DEPARTAMENTO     Total
# 0                    AMAZONAS    155506
# 1                   ANTIOQUIA  13100412
# 2                      ARAUCA    560218
# 3  ARCHIPIÉLAGO DE SAN ANDRÉS    124964
# 4                   ATLÁNTICO   5276302

# %%
Y = pd.DataFrame(Y)
Y
# Out:
#                   DEPARTAMENTO  ABIGEATO  ...  TERRORISMO  VIOLENCIA_INTRAFAMILIAR
# 0                     AMAZONAS       0.0  ...         0.0                    134.0
# 1                    ANTIOQUIA     178.0  ...        71.0                  16890.0
# 2                       ARAUCA      37.0  ...        63.0                    382.0
# 3   ARCHIPIÉLAGO DE SAN ANDRÉS       0.0  ...         0.0                    154.0
# 4                    ATLÁNTICO      73.0  ...         0.0                   3161.0
# 5                      BOLÍVAR     239.0  ...         0.0                   3398.0
# 6                       BOYACÁ     129.0  ...         1.0                   3651.0
# 7                       CALDAS      30.0  ...         0.0                   1400.0
# 8                      CAQUETÁ      20.0  ...         2.0                    502.0
# 9                     CASANARE     212.0  ...         0.0                    705.0
# ...

# %%
df_group = poblacion.merge(Y, how = 'inner', on='DEPARTAMENTO');df_group
# Out:
#                   DEPARTAMENTO     Total  ...  TERRORISMO  VIOLENCIA_INTRAFAMILIAR
# 0                     AMAZONAS    155506  ...         0.0                    134.0
# 1                    ANTIOQUIA  13100412  ...        71.0                  16890.0
# 2                       ARAUCA    560218  ...        63.0                    382.0
# 3   ARCHIPIÉLAGO DE SAN ANDRÉS    124964  ...         0.0                    154.0
# 4                    ATLÁNTICO   5276302  ...         0.0                   3161.0
# 5                      BOLÍVAR   4261024  ...         0.0                   3398.0
# 6                       BOYACÁ   2461820  ...         1.0                   3651.0
# 7                       CALDAS   2016688  ...         0.0                   1400.0
# 8                      CAQUETÁ    812284  ...         2.0                    502.0
# 9                     CASANARE    857126  ...         0.0                    705.0
# ...

# %%
A = poblacion['DEPARTAMENTO']
A = pd.DataFrame(A)

# %%
B = Y['DEPARTAMENTO']
B = pd.DataFrame(B)

# %%
df = A.merge(B, how='outer', indicator='union')

# %%
df[df['union'] == 'right_only'] #POLICIA
# Out:
#    DEPARTAMENTO       union
# 32  NO REGISTRA  right_only

# %%
df[df['union'] == 'left_only'] #DANE
# Out:
# Empty DataFrame
# Columns: [DEPARTAMENTO, union]
# Index: []

# %%
df_group["ABIGEATO"] = (df_group["ABIGEATO"]/df_group["Total"])*100000
df_group["AMENAZAS"] = (df_group["AMENAZAS"]/df_group["Total"])*100000
df_group["DELITOS_SEXUALES"] = (df_group["DELITOS_SEXUALES"]/df_group["Total"])*100000
df_group["EXTORSION"] = (df_group["EXTORSION"]/df_group["Total"])*100000
df_group["HOMICIDIOS"] = (df_group["HOMICIDIOS"]/df_group["Total"])*100000
df_group["HOMICIDIOS_TRANSITO"] = (df_group["HOMICIDIOS_TRANSITO"]/df_group["Total"])*100000
df_group["HURTO_AUTOMOTORES"] = (df_group["HURTO_AUTOMOTORES"]/df_group["Total"])*100000
df_group["HURTO_COMERCIO"] = (df_group["HURTO_COMERCIO"]/df_group["Total"])*100000
df_group["HURTO_ENTIDADES"] = (df_group["HURTO_ENTIDADES"]/df_group["Total"])*100000
df_group["HURTO_MOTOCICLETAS"] = (df_group["HURTO_MOTOCICLETAS"]/df_group["Total"])*100000
df_group["HURTO_PERSONAS"] = (df_group["HURTO_PERSONAS"]/df_group["Total"])*100000
df_group["HURTO_RESIDENCIAS"] = (df_group["HURTO_RESIDENCIAS"]/df_group["Total"])*100000
df_group["LESIONES_ACCIDENTES"] = (df_group["LESIONES_ACCIDENTES"]/df_group["Total"])*100000
df_group["LESIONES_PERSONALES"] = (df_group["LESIONES_PERSONALES"]/df_group["Total"])*100000
df_group["PIRATERIA_TERRESTRE"] = (df_group["PIRATERIA_TERRESTRE"]/df_group["Total"])*100000
df_group["SECUESTRO"] = (df_group["SECUESTRO"]/df_group["Total"])*100000
df_group["TERRORISMO"] = (df_group["TERRORISMO"]/df_group["Total"])*100000
df_group["VIOLENCIA_INTRAFAMILIAR"] = (df_group["VIOLENCIA_INTRAFAMILIAR"]/df_group["Total"])*100000

# %%
del df_group['Total']

# %%
df_group
# Out:
#                   DEPARTAMENTO   ABIGEATO  ...  TERRORISMO  VIOLENCIA_INTRAFAMILIAR
# 0                     AMAZONAS   0.000000  ...    0.000000                86.170309
# 1                    ANTIOQUIA   1.358736  ...    0.541968               128.927243
# 2                       ARAUCA   6.604572  ...   11.245622                68.187741
# 3   ARCHIPIÉLAGO DE SAN ANDRÉS   0.000000  ...    0.000000               123.235492
# 4                    ATLÁNTICO   1.383545  ...    0.000000                59.909384
# 5                      BOLÍVAR   5.608980  ...    0.000000                79.746089
# 6                       BOYACÁ   5.240026  ...    0.040620               148.304913
# 7                       CALDAS   1.487588  ...    0.000000                69.420753
# 8                      CAQUETÁ   2.462193  ...    0.246219                61.801045
# 9                     CASANARE  24.733820  ...    0.000000                82.251618
# ...

# %% [markdown]
# #PCA

# %%
df_1 = df_group.values
df_1[5]
# Out:
# array(['BOLÍVAR', 5.608980376547985, 43.534136395382895,
#        32.90288907079613, 4.646770353792891, 8.988449724760995,
#        4.717175965213995, 2.4407278625982864, 46.49117207506928,
#        0.07040561142110441, 30.767252191022628, 171.5315379589507,
#        33.653882259287904, 7.815022867742591, 114.83155222782129,
#        0.3050909828247858, 0.04693707428073628, 0.0, 79.74608920297092],
#       dtype=object)

# %%
df_2 = np.delete(df_1, 0, axis=1)
df_2[5]
# Out:
# array([5.608980376547985, 43.534136395382895, 32.90288907079613,
#        4.646770353792891, 8.988449724760995, 4.717175965213995,
#        2.4407278625982864, 46.49117207506928, 0.07040561142110441,
#        30.767252191022628, 171.5315379589507, 33.653882259287904,
#        7.815022867742591, 114.83155222782129, 0.3050909828247858,
#        0.04693707428073628, 0.0, 79.74608920297092], dtype=object)

# %%
df_group.corr(method='pearson')
# Out:
#                          ABIGEATO  ...  VIOLENCIA_INTRAFAMILIAR
# ABIGEATO                 1.000000  ...                -0.077510
# AMENAZAS                 0.109005  ...                 0.091492
# DELITOS_SEXUALES        -0.184521  ...                 0.312381
# EXTORSION                0.293786  ...                -0.035075
# HOMICIDIOS              -0.242607  ...                -0.152961
# HOMICIDIOS_TRANSITO      0.293133  ...                 0.179748
# HURTO_AUTOMOTORES       -0.075753  ...                 0.282100
# HURTO_COMERCIO           0.011188  ...                 0.574937
# HURTO_ENTIDADES         -0.152329  ...                 0.197982
# HURTO_MOTOCICLETAS       0.059548  ...                -0.002838
# HURTO_PERSONAS          -0.017366  ...                 0.702656
# HURTO_RESIDENCIAS        0.362304  ...                 0.427000
# LESIONES_ACCIDENTES      0.018784  ...                 0.434225
# LESIONES_PERSONALES      0.023613  ...                 0.593149
# ...

# %%
X_scal = np.zeros(df_2.shape)
for i in range(X_scal.shape[1]):
  X_scal[:,i] = (df_2[:,i] - df_2[:,i].mean())/(df_2[:,i].std())

# %%
X_scal[:5]
# Out:
# array([[-0.90290132, -0.05246676,  3.07974071, -1.04222893, -1.31606716,
#         -1.4700978 , -0.78421357,  1.04793974, -0.63796199, -0.53538161,
#         -0.61931241,  0.93790483, -1.15633702,  1.06329286, -0.33483358,
#         -0.50702001, -0.22460369, -0.0399802 ],
#        [-0.61836465, -1.61311679, -0.29078705,  0.22978389,  0.72010778,
#         -0.19676805,  1.13474527,  1.00460264, -0.09855172,  1.45438437,
#          0.97479559, -0.22804278,  0.24964024, -0.36642755, -0.15578276,
#         -0.37027197,  0.05386364,  1.07928615],
#        [ 0.48018044,  0.90566098,  0.5984019 ,  2.76287353,  2.23310757,
#          1.19730057,  0.70490027, -0.43073004, -0.63796199,  0.59656245,
#         -0.74729953, -0.18653361, -0.48360157, -0.61133117,  5.46256761,
#          2.69076309,  5.55348686, -0.51071746],
#        [-0.90290132, -0.59195893,  1.22188775, -0.86336085,  1.00398993,
#          3.95216671, -0.65583377,  2.2364075 ,  4.50278901,  1.19179809,
# ...

# %%
cov = X_scal.T.dot(X_scal)/X_scal.shape[0]

# %%
X_scal.shape[0]
# Out:
# 32

# %%
cov[5]
# Out:
# array([0.29313255, 0.17570908, 0.02962056, 0.27575002, 0.40862727,
#        1.        , 0.1392487 , 0.3875787 , 0.53291486, 0.45860202,
#        0.25710851, 0.51587013, 0.47561224, 0.58298354, 0.22532949,
#        0.49707327, 0.21976846, 0.17974826])

# %%
eigvals, eigvecs = np.linalg.eig(cov)

# %%
eigvals
# Out:
# array([4.56602541, 3.70845666, 2.11282786, 1.8012094 , 1.43905762,
#        1.39468381, 0.82721597, 0.60768431, 0.40073671, 0.32160922,
#        0.2476153 , 0.19980187, 0.00850661, 0.11741973, 0.03637035,
#        0.05332908, 0.0867412 , 0.07070888])

# %%
eigvecs[5]
# Out:
# array([ 0.34176357,  0.18551953, -0.02949811, -0.07676749, -0.40812301,
#         0.03462422,  0.1368696 ,  0.01907691, -0.09494524, -0.00339233,
#        -0.09690874, -0.29993292, -0.01302282, -0.28412359, -0.18668136,
#        -0.26969401,  0.59236341, -0.0860474 ])

# %%
varianza_explicada = {i:i/sum(eigvals) for i in eigvals};varianza_explicada
# Out:
# {0.008506611614897656: 0.0004725895341609805,
#  0.03637035415459134: 0.0020205752308106286,
#  0.0533290790288735: 0.002962726612715192,
#  0.07070887594175823: 0.003928270885653232,
#  0.0867412034581551: 0.00481895574767528,
#  0.11741973394418052: 0.006523318552454469,
#  0.19980186895566476: 0.011100103830870256,
#  0.247615302433311: 0.01375640569073949,
#  0.32160922138433146: 0.017867178965796177,
#  0.40073670790327853: 0.02226315043907101,
#  0.6076843147652305: 0.03376023970917945,
#  0.8272159741441907: 0.04595644300801056,
#  1.3946838104460708: 0.07748243391367055,
#  1.43905761539707: 0.07994764529983715,
#  1.801209396444894: 0.10006718869138292,
#  2.1128278555569606: 0.11737932530871995,
#  3.708456661378737: 0.20602537007659635,
#  4.566025413047818: 0.2536680785026564}

# %%
inercia = pd.DataFrame({'eigvalues': eigvals,
                        'inercia_acum': np.cumsum(eigvals),
                        'Var_expl': varianza_explicada.values(),
                        'Var_expl_acum':np.cumsum([i for i in varianza_explicada.values()])})

# %%
inercia
# Out:
#     eigvalues  inercia_acum  Var_expl  Var_expl_acum
# 0    4.566025      4.566025  0.253668       0.253668
# 1    3.708457      8.274482  0.206025       0.459693
# 2    2.112828     10.387310  0.117379       0.577073
# 3    1.801209     12.188519  0.100067       0.677140
# 4    1.439058     13.627577  0.079948       0.757088
# 5    1.394684     15.022261  0.077482       0.834570
# 6    0.827216     15.849477  0.045956       0.880526
# 7    0.607684     16.457161  0.033760       0.914287
# 8    0.400737     16.857898  0.022263       0.936550
# 9    0.321609     17.179507  0.017867       0.954417
# 10   0.247615     17.427122  0.013756       0.968173
# 11   0.199802     17.626924  0.011100       0.979274
# 12   0.008507     17.635431  0.000473       0.979746
# 13   0.117420     17.752850  0.006523       0.986269
# 14   0.036370     17.789221  0.002021       0.988290
# 15   0.053329     17.842550  0.002963       0.991253
# 16   0.086741     17.929291  0.004819       0.996072
# ...

# %%
import matplotlib.pyplot as plt
# A partir de los autovalores, calculamos la varianza explicada
tot = sum(eigvals)
var_exp = [(i / tot)*100 for i in sorted(eigvals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)

# Representamos en un diagrama de barras la varianza explicada por cada autovalor, y la acumulada
with plt.style.context('seaborn-pastel'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(18), var_exp, alpha=0.5, align='center',
            label='Varianza individual explicada', color='g')
    plt.step(range(18), cum_var_exp, where='mid', linestyle='--', label='Varianza explicada acumulada')
    plt.ylabel('Ratio de Varianza Explicada')
    plt.xlabel('Componentes Principales')
    plt.legend(loc='best')
    plt.tight_layout()

# %%
proyec = X_scal.dot(eigvecs[:,:2])

# %%
proyec = pd.DataFrame(proyec, columns=['PC1', 'PC2'])
proyec.head()
# Out:
#         PC1       PC2
# 0 -0.100342 -2.314763
# 1  1.064097  0.113578
# 2  0.605066  8.127096
# 3  7.588479 -0.138221
# 4 -0.771822 -1.004602

# %%
#GRAFICO
x = df_group['DEPARTAMENTO']
x = pd.DataFrame(x)
data = pd.concat([x,proyec],axis=1)
import plotly.express as px
df = px.data.iris()
fig = px.scatter(data, x='PC1', y='PC2', hover_name="DEPARTAMENTO", color="DEPARTAMENTO")
fig.show() #SE QUE LOS COLORES NO SIRVEN PERO SE VE LINDO :C
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="73e332fc-fddd-426a-9dbb-a0cd1f3fab3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("73e332fc-fddd-426a-9dbb-a0cd1f3fab3e")) {
#                     Plotly.newPlot(
#                         '73e332fc-fddd-426a-9dbb-a0cd1f3fab3e',
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (Seria correcto hacer el ACP con tres componentes principales)
# Se puede analizar que:
#
# • El porcentaje de variabilidad explicado por la primera componente principal es 25.4%
#
# • El porcentaje de variabilidad explicado por la segunda compontente principal es 20.6%
#
# • Juntas acumulan un porcentaje de variabilidad del 45.96%
#
# • Las variables que estan mejor representadas en la dimension 1 son: Homicidios Transito, Hurto Comercio y Lesiones Personales.
#
# • Las variables que estan mejor representadas en la dimension 2 son: Homicidios, Extorsión, Terrorismo y Pirateria terrestre.
#
# • Aquellas variables que se asocian de forma positiva y fuerte:
# - Hurto Comercio con Lesiones Personales, esto quiere decir por ejemplo que si sube el hurto relacionado al comercio se incrementan los casos de lesiones personales
# - Terrorismo y Pirateria Terrestre
# - Terrorismo y Extorsión.
# - Pirateria Terrestre, Terrorismo y Extorsión tienen una asociación positiva media con homicidios.
# - Pirateria Terrestre, Terrorismo y Extorsión tienen una asociación positiva baja con homicidios por tránsito.
# - Lesiones Personales y Hurto Comercio tienen una asociación positiva baja con homicidios por tránsito.
#
# • Aquellas variables que se asocian negativamente:
# - Pirateria Terrestre, Terrorismo y Extorsión tienen una asociación negativa baja con Lesiones Personales y Hurto Comercio.
#
# •En cuanto a los departamentos se puede observar que:
# - Los departamentos de Cundinamarca, Tolima, Quindio, Risaralda, Santander, Casanare y Huila son aquellos que tienen mayores casos de hurto comercial y lesiones personales
# -Los departamentos de Antioquia, Meta y Valle del Cauca cuentan con los mayores casos de homicidios por transito.
# - Quien tiene el mayor caso de homicidios es el departamento del Cauca.
# - El departamento de Vichada tiene los menores casos de delitos.
# - El departamento de Vaupes cuenta con los menores casos de hurto de motocicletas.
# - Amazonas podria tener los menores casos de terrorismo y extorsión.
# - Chocó y Putumayo tendrian los mejores casos en lesiones personales y hurto comercial.
#
# [Todos los casos por cada tipo de delito divididos entre la poblacion de su respectivo departamento y multiplicado por 100.000 de personas]

# %%
proyec2 = X_scal.dot(eigvecs[:,:3])
proyec2 = pd.DataFrame(proyec2, columns=['PC1', 'PC2', 'PC3'])
proyec2.head()
# Out:
#         PC1       PC2       PC3
# 0 -0.100342 -2.314763 -2.228672
# 1  1.064097  0.113578  1.974590
# 2  0.605066  8.127096 -2.243102
# 3  7.588479 -0.138221  0.432225
# 4 -0.771822 -1.004602  1.563175

# %%
#GRAFICO
x = df_group['DEPARTAMENTO']
x = pd.DataFrame(x)
data = pd.concat([x,proyec2],axis=1)
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(data, x='PC1', y='PC2', z = 'PC3', 
                    hover_name="DEPARTAMENTO", color="DEPARTAMENTO")
fig.show() #SE QUE LOS COLORES NO SIRVEN PERO SE VE LINDO
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="db550b9a-e480-4491-9776-b0767dc8a2dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db550b9a-e480-4491-9776-b0767dc8a2dc")) {
#                     Plotly.newPlot(
#                         'db550b9a-e480-4491-9776-b0767dc8a2dc',
# ...
